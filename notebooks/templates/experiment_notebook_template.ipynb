# %% [markdown]
# # EXP-XXXX - Experiment Title
#
# Canonical protocol: `docs/experiments/EXP-XXXX-short-title.md`
#
# Status: Draft | Running | Validated | Failed | Pending

# %% [markdown]
# ## Notebook Purpose
#
# Use this notebook to document evidence, outputs, observations, and lightweight analysis. Keep robot control commands in validated terminals or scripts unless the experiment explicitly requires notebook execution.

# %% [markdown]
# ## Objective
#
# TBD

# %% [markdown]
# ## Preconditions
#
# - TBD

# %% [markdown]
# ## Commands Executed Externally
#
# ```bash
# # Paste validated terminal commands here.
# ```

# %% [markdown]
# ## Observed Results
#
# Paste or summarize terminal output, screenshots, logs, CSV paths, or JSON paths here.

# %%
from pathlib import Path

repo_root = Path.cwd().resolve()
repo_root

# %% [markdown]
# ## Analysis
#
# Add Python analysis cells only for exported evidence, generated data, tables, or plots.

# %% [markdown]
# ## Conclusion
#
# TBD
