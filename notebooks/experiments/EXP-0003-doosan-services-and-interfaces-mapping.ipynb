# %% [markdown]
# # EXP-0003 - Doosan Services and Interfaces Mapping
#
# Canonical protocol: `docs/experiments/EXP-0003-doosan-services-and-interfaces-mapping.md`
#
# Status: Validated

# %% [markdown]
# ## Objective
#
# Map available Doosan ROS 2 packages, services, and interfaces before designing future adapter code.

# %% [markdown]
# ## External Commands
#
# ```bash
# source ~/doosan_ws/install/setup.bash
# ros2 pkg list | grep dsr
# ros2 pkg prefix dsr_msgs2
# ros2 interface list | grep dsr_msgs2
# ros2 interface list | grep "dsr_msgs2/srv"
# ros2 interface show dsr_msgs2/srv/MoveJoint
# ros2 interface show dsr_msgs2/srv/MoveLine
# ros2 service list | grep dsr
# ros2 service type /dsr01/dsr_controller2/motion/move_joint
# ```

# %% [markdown]
# ## Observed Result
#
# Validated. `dsr_msgs2`, `MoveJoint`, `MoveLine`, and active Doosan services were available after sourcing the official Doosan workspace.

# %% [markdown]
# ## Relevant Interfaces
#
# | Interface | Use |
# |---|---|
# | `dsr_msgs2/srv/MoveJoint` | Joint-space motion baseline. |
# | `dsr_msgs2/srv/MoveLine` | Cartesian linear motion baseline. |
# | `/dsr01/dsr_controller2/motion/move_joint` | Validated active motion service. |

# %%
from pathlib import Path

evidence_dir = Path('notebooks/evidence/EXP-0003').resolve()
evidence_dir

# %% [markdown]
# ## Conclusion
#
# The official Doosan service interfaces provide a clear baseline for future direct service-based experiments and adapter design.
