# %% [markdown]
# # EXP-0006 - Gazebo Simulation Validation
#
# Canonical protocol: `docs/experiments/EXP-0006-gazebo-simulation-validation.md`
#
# Status: Validated

# %% [markdown]
# ## Objective
#
# Validate that Gazebo can launch and simulate the Doosan `m1013` in the local ROS 2 Jazzy environment.

# %% [markdown]
# ## External Commands
#
# ```bash
# cd ~/doosan_ws
# source ~/doosan_ws/install/setup.bash
# ros2 launch dsr_bringup2 dsr_bringup2_gazebo.launch.py --show-args
# ros2 launch dsr_bringup2 dsr_bringup2_gazebo.launch.py mode:=virtual host:=127.0.0.1 port:=12346 name:=dsr01 model:=m1013 x:=0 y:=0
#
# source ~/doosan_ws/install/setup.bash
# ros2 node list
# ros2 topic list
# ros2 service list | grep dsr
# ros2 topic echo /dsr01/joint_states
# ```

# %% [markdown]
# ## Observed Result
#
# Validated. Gazebo launched with the Doosan `m1013`, exposed robot state information, and no blocking warnings or errors were identified.

# %% [markdown]
# ## Tool Separation
#
# | Tool | Practical Role |
# |---|---|
# | RViz2 | Visualization. |
# | MoveIt2 | Planning. |
# | Gazebo | Simulation environment. |

# %%
from pathlib import Path

evidence_dir = Path('notebooks/evidence/EXP-0006').resolve()
evidence_dir

# %% [markdown]
# ## Conclusion
#
# Gazebo is suitable for future experiments requiring simulation beyond visualization or planning alone.
